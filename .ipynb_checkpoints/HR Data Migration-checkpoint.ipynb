# %% [markdown]
# ## Data Migration to MySQL Database
#
# In this project i imported data fro a csv file to a MySQL database using some of the libraries provided by python.
#
# In summary the project involved:
# 1. Loading my required python libraries.
# 2. Connecting to my already created MySQL database.
# 3. Importing my data from a csv file into a dataframe.
# 4. Doing some basic data cleaning to ensure that the data format is in order.
# 5. Migrating my dataframe to my MySQl database as a table.

# %% [markdown]
# ### Loading my required libraries

# %%
import pandas as pd
import pyodbc
import os
import re
from sqlalchemy import create_engine
import psycopg2 as pg2
import mysql.connector as msc
from decimal import Decimal
from datetime import datetime, date

# %% [markdown]
# ### Connecting to my database
#
# Ensure to replace the "****" with your actual password

# %%
mysql_conn = msc.connect(database='tdi_test', user= "root", password="****", port=3306)

# %%
mysql_engine = create_engine(f'mysql://root:****@localhost/tdi_test')

# %% [markdown]
# ### Importing my dataset

# %%
df = pd.read_csv('HR_DATA.csv')
df
# Out:
#                id first_name    last_name   birthdate gender  \
# 0      00-0037846      Kimmy   Walczynski  04/06/1991      M
# 1      00-0041533   Ignatius    Springett  29/06/1984      M
# 2      00-0045747     Corbie  Bittlestone  29/07/1989      M
# 3      00-0055274       Baxy       Matton  14/09/1982     FM
# 4      00-0076100    Terrell         Suff  11/04/1994     FM
# ...           ...        ...          ...         ...    ...
# 22222  99-9797418    Dorella       Garvan  08/07/1998     FM
# 22223  99-9869877      Dasie      Thorsby  19/04/2001     FM
# 22224  99-9919822      Nerty      Wilding  09/02/1970     FM
# 22225  99-9960380    Mabelle        Dawks  02/09/1985      M
# 22226  99-9963543    Carroll    Chattaway  10/07/1999     FM
#
#                             race                department  \
# 0             Hispanic or Latino               Engineering
# 1                          White      Business Development
# 2      Black or African American                     Sales
# 3                          White                  Services
# 4              Two or More Races        Product Management
# ...                          ...                       ...
# 22222         Hispanic or Latino  Research and Development
# 22223          Two or More Races                  Services
# 22224          Two or More Races                  Training
# 22225          Two or More Races                Accounting
# 22226                      White               Engineering
#
#                          jobtitle      location   hire_date  \
# 0            Programmer Analyst I  Headquarters  20/01/2002
# 1                Business Analyst  Headquarters  08/04/2019
# 2      Solutions Engineer Manager  Headquarters  12/10/2010
# 3                    Service Tech  Headquarters  10/04/2005
# 4                Business Analyst        Remote  29/09/2010
# ...                           ...           ...         ...
# 22222        Research Assistant I  Headquarters  08/02/2012
# 22223             Service Manager  Headquarters  06/10/2017
# 22224              Junior Trainer  Headquarters  08/02/2001
# 22225          Staff Accountant I  Headquarters  03/04/2005
# 22226       Software Engineer III        Remote  27/03/2018
#
#                       termdate location_city location_state
# 0                          NaN     Cleveland           Ohio
# 1                          NaN     Cleveland           Ohio
# 2                          NaN     Cleveland           Ohio
# 3                          NaN     Cleveland           Ohio
# 4      2029-10-29 06:09:38 UTC         Flint       Michigan
# ...                        ...           ...            ...
# 22222                      NaN     Cleveland           Ohio
# 22223                      NaN     Cleveland           Ohio
# 22224                      NaN     Cleveland           Ohio
# 22225  2012-12-10 14:29:59 UTC     Cleveland           Ohio
# 22226                      NaN    Fort Wayne        Indiana
#
# [22227 rows x 13 columns]

# %% [markdown]
# #### Viewing some basic information about the imported dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22227 entries, 0 to 22226
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22227 non-null  object
#  1   first_name      22227 non-null  object
#  2   last_name       22227 non-null  object
#  3   birthdate       22227 non-null  object
#  4   gender          22227 non-null  object
#  5   race            22227 non-null  object
#  6   department      22227 non-null  object
#  7   jobtitle        22227 non-null  object
#  8   location        22227 non-null  object
#  9   hire_date       22227 non-null  object
#  10  termdate        3932 non-null   object
#  11  location_city   22227 non-null  object
#  12  location_state  22227 non-null  object
# dtypes: object(13)
# memory usage: 2.2+ MB

# %% [markdown]
# ### Converting dates imported as text into datetine format

# %%
df['birthdate'] = pd.to_datetime(df['birthdate'], format="%d/%m/%Y")
df['hire_date'] = pd.to_datetime(df['hire_date'], format="%d/%m/%Y")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22227 entries, 0 to 22226
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22227 non-null  object
#  1   first_name      22227 non-null  object
#  2   last_name       22227 non-null  object
#  3   birthdate       22227 non-null  datetime64[ns]
#  4   gender          22227 non-null  object
#  5   race            22227 non-null  object
#  6   department      22227 non-null  object
#  7   jobtitle        22227 non-null  object
#  8   location        22227 non-null  object
#  9   hire_date       22227 non-null  datetime64[ns]
#  10  termdate        3932 non-null   object
#  11  location_city   22227 non-null  object
#  12  location_state  22227 non-null  object
# dtypes: datetime64[ns](2), object(11)
# memory usage: 2.2+ MB

# %%
df['termdate'] = pd.to_datetime(df['termdate'], format="mixed")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22227 entries, 0 to 22226
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22227 non-null  object
#  1   first_name      22227 non-null  object
#  2   last_name       22227 non-null  object
#  3   birthdate       22227 non-null  datetime64[ns]
#  4   gender          22227 non-null  object
#  5   race            22227 non-null  object
#  6   department      22227 non-null  object
#  7   jobtitle        22227 non-null  object
#  8   location        22227 non-null  object
#  9   hire_date       22227 non-null  datetime64[ns]
#  10  termdate        3932 non-null   datetime64[ns, UTC]
#  11  location_city   22227 non-null  object
#  12  location_state  22227 non-null  object
# dtypes: datetime64[ns, UTC](1), datetime64[ns](2), object(10)
# memory usage: 2.2+ MB

# %% [markdown]
# ### Converting the datetime to date format

# %%
df['birthdate'] = df['birthdate'].dt.date
df['hire_date'] = df['hire_date'].dt.date
df['termdate'] = df['termdate'].dt.date
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22227 entries, 0 to 22226
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22227 non-null  object
#  1   first_name      22227 non-null  object
#  2   last_name       22227 non-null  object
#  3   birthdate       22227 non-null  datetime64[ns]
#  4   gender          22227 non-null  object
#  5   race            22227 non-null  object
#  6   department      22227 non-null  object
#  7   jobtitle        22227 non-null  object
#  8   location        22227 non-null  object
#  9   hire_date       22227 non-null  datetime64[ns]
#  10  termdate        3932 non-null   object
#  11  location_city   22227 non-null  object
#  12  location_state  22227 non-null  object
# dtypes: datetime64[ns](2), object(11)
# memory usage: 2.2+ MB

# %%
df
# Out:
#                id first_name    last_name  birthdate gender  \
# 0      00-0037846      Kimmy   Walczynski 1991-06-04      M
# 1      00-0041533   Ignatius    Springett 1984-06-29      M
# 2      00-0045747     Corbie  Bittlestone 1989-07-29      M
# 3      00-0055274       Baxy       Matton 1982-09-14     FM
# 4      00-0076100    Terrell         Suff 1994-04-11     FM
# ...           ...        ...          ...        ...    ...
# 22222  99-9797418    Dorella       Garvan 1998-07-08     FM
# 22223  99-9869877      Dasie      Thorsby 2001-04-19     FM
# 22224  99-9919822      Nerty      Wilding 1970-02-09     FM
# 22225  99-9960380    Mabelle        Dawks 1985-09-02      M
# 22226  99-9963543    Carroll    Chattaway 1999-07-10     FM
#
#                             race                department  \
# 0             Hispanic or Latino               Engineering
# 1                          White      Business Development
# 2      Black or African American                     Sales
# 3                          White                  Services
# 4              Two or More Races        Product Management
# ...                          ...                       ...
# 22222         Hispanic or Latino  Research and Development
# 22223          Two or More Races                  Services
# 22224          Two or More Races                  Training
# 22225          Two or More Races                Accounting
# 22226                      White               Engineering
#
#                          jobtitle      location  hire_date    termdate  \
# 0            Programmer Analyst I  Headquarters 2002-01-20         NaT
# 1                Business Analyst  Headquarters 2019-04-08         NaT
# 2      Solutions Engineer Manager  Headquarters 2010-10-12         NaT
# 3                    Service Tech  Headquarters 2005-04-10         NaT
# 4                Business Analyst        Remote 2010-09-29  2029-10-29
# ...                           ...           ...        ...         ...
# 22222        Research Assistant I  Headquarters 2012-02-08         NaT
# 22223             Service Manager  Headquarters 2017-10-06         NaT
# 22224              Junior Trainer  Headquarters 2001-02-08         NaT
# 22225          Staff Accountant I  Headquarters 2005-04-03  2012-12-10
# 22226       Software Engineer III        Remote 2018-03-27         NaT
#
#       location_city location_state
# 0         Cleveland           Ohio
# 1         Cleveland           Ohio
# 2         Cleveland           Ohio
# 3         Cleveland           Ohio
# 4             Flint       Michigan
# ...             ...            ...
# 22222     Cleveland           Ohio
# 22223     Cleveland           Ohio
# 22224     Cleveland           Ohio
# 22225     Cleveland           Ohio
# 22226    Fort Wayne        Indiana
#
# [22227 rows x 13 columns]

# %% [markdown]
# ### Migrating the dataframe to my database as a table.

# %%
df.to_sql('hr_data', con=mysql_engine, if_exists='replace', index=False)
# Out:
# 22227
